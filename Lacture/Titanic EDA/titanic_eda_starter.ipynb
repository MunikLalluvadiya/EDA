# %% [markdown]
# # Titanic EDA Practice
#
# A guided walkthrough of the 8-step EDA process. Fill in the `# TODO` cells yourself, then compare against the hints below each one.

# %% [markdown]
# ## Step 1-2: Load and inspect structure

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('titanic.csv')
df.shape

# %%
df.info()

# %%
df.head()

# %% [markdown]
# ## Step 3: Check for missing and duplicate data

# %%
df.isnull().sum()

# %%
df.duplicated().sum()

# %% [markdown]
# **Your turn:** `Age`, `Cabin`, and `Embarked` all have missing values. For each one, decide: drop, fill with median/mode, or flag as its own category? Write your reasoning here.
#
# - Age:
# - Cabin:
# - Embarked:

# %% [markdown]
# ## Step 4: Descriptive statistics

# %%
df.describe()

# %%
df['Sex'].value_counts()

# %%
# TODO: run value_counts() on Pclass and Embarked too

# %% [markdown]
# ## Step 5: Visualize distributions

# %%
df['Age'].hist(bins=30)
plt.xlabel('Age')
plt.title('Age Distribution')
plt.show()

# %%
sns.boxplot(x=df['Fare'])
plt.title('Fare Boxplot (look for outliers)')
plt.show()

# %%
# TODO: plot a bar chart of df['Pclass'].value_counts()

# %% [markdown]
# ## Step 6: Explore relationships between variables

# %%
numeric_df = df.select_dtypes(include=[np.number])
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.barplot(data=df, x='Pclass', y='Survived')
plt.title('Survival Rate by Class')
plt.show()

# %%
# TODO: compare survival rate by Sex the same way

# %% [markdown]
# ## Step 7: Form and test hypotheses
#
# Pick 3-5 questions and answer each with a chart or a `groupby`. Examples to get you started:
#
# - Did women have a higher survival rate than men?
# - Did passengers who paid higher fares survive more often?
# - Did having family aboard (SibSp + Parch) change survival odds?

# %%
# TODO: answer question 1
df.groupby('Sex')['Survived'].mean()

# %%
# TODO: answer question 2

# %%
# TODO: answer question 3

# %% [markdown]
# ## Step 8: Summary of findings
#
# Write 3-5 bullet points here summarizing what you found and why it matters, as if presenting to someone who hasn't seen the data.
#
# -
# -
# -
